# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

'''url = 'https://data.tuik.gov.tr/Bulten/DownloadIstatistikselTablo?p=rwL9QycYSf8RfKlp6oK9EQqrlMKBxFUMm8c426xFcUpXWBn6WiuEr0CJZ6dx7Knz.xls'
okuma_orani = pd.read_csv(url)
okuma_orani.info()'''
'''data = pd.read_excel('https://data.tuik.gov.tr/Bulten/DownloadIstatistikselTablo?p=rwL9QycYSf8RfKlp6oK9EQqrlMKBxFUMm8c426xFcUpXWBn6WiuEr0CJZ6dx7Knz')
data.info()'''
'''data = 'C:/Users/MURAT/Downloads/education1.csv'
data = pd.read_csv(data)'''

from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
data = pd.read_csv('gdrive/My Drive/education1.csv',sep=';', index_col=0)
# Out:
# Mounted at /content/gdrive

# %%
#verimizi gösterdik
data
# Out:
#       Total Illiterate  ... Master Doctorate
# Year                    ...
# 2010    100          9  ...    0,9       0,3
# 2011    100        7,2  ...      1       0,3
# 2012    100        6,3  ...      1       0,3
# 2013    100        5,9  ...    1,2       0,4
# 2014    100        5,7  ...    1,3       0,4
# 2015    100        5,5  ...    1,4       0,4
# 2016    100        5,1  ...    1,4       0,4
# 2017    100        4,8  ...    1,8       0,4
# 2018    100        4,5  ...      2       0,4
# 2019    100        4,1  ...    2,2       0,4
# 2020    100        3,8  ...    2,2       0,4
#
# [11 rows x 10 columns]

# %%
#veride null olup olmadığına baktık
data.isnull()
# Out:
#       Total  Illiterate  ...  Master  Doctorate
# Year                     ...
# 2010  False       False  ...   False      False
# 2011  False       False  ...   False      False
# 2012  False       False  ...   False      False
# 2013  False       False  ...   False      False
# 2014  False       False  ...   False      False
# 2015  False       False  ...   False      False
# 2016  False       False  ...   False      False
# 2017  False       False  ...   False      False
# 2018  False       False  ...   False      False
# 2019  False       False  ...   False      False
# 2020  False       False  ...   False      False
#
# [11 rows x 10 columns]

# %%
#data.drop(['Total','Illiterate',literate without diploma'	Primary school	Primary education	Junior high school and equivalent	High school and equivalent	Higher education	Master	Doctorate], axis=1)

# %%
#çizgi grafik
sns.lineplot(data=data['Primary school'])

# %%
#pasta grafik
data['Primary school'].value_counts().plot.pie()

# %%
#verinin içindeki virgülleri nokta yaptık
for col in data.columns:
    if type(data[col].values[0]) == str:
        data[col] = data[col].apply(lambda x : x.replace(",","."))
        data[col] = data[col].apply(lambda x : float(x))
#sns.heatmap(data.corr(), annot=True, linewidths=0.5,linecolor="red", fmt= '.1f')

# %%
#sütun grafiği
plt.figure(figsize=(10,6))


plt.title("Primary Education, by Year")


sns.barplot(x=data.index, y=data['Primary education'])


plt.ylabel("Primary Education")
# Out:
# Text(0, 0.5, 'Primary Education')

# %%
data.columns
# Out:
# Index(['Total', 'Illiterate', 'literate without diploma', 'Primary school',
#        'Primary education', 'Junior high school and equivalent ',
#        'High school and equivalent', 'Higher education ', 'Master',
#        'Doctorate'],
#       dtype='object')

# %%
#data["Master"] = data["Master"].apply(lambda x : x.replace(",","."))

#data['Master'] = data['Master'].astype('float')

for col in data.columns:
    print(type(col))
    if type(col) == 'str':
      data[col] = data[col].apply(lambda x : x.replace(",","."))
      data[col] = data[col].astype('float')
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
data.head
# Out:
# <bound method NDFrame.head of       Total  Illiterate  ...  Master  Doctorate
# Year                     ...
# 2010    100         9.0  ...     0.9        0.3
# 2011    100         7.2  ...     1.0        0.3
# 2012    100         6.3  ...     1.0        0.3
# 2013    100         5.9  ...     1.2        0.4
# 2014    100         5.7  ...     1.3        0.4
# 2015    100         5.5  ...     1.4        0.4
# 2016    100         5.1  ...     1.4        0.4
# 2017    100         4.8  ...     1.8        0.4
# 2018    100         4.5  ...     2.0        0.4
# 2019    100         4.1  ...     2.2        0.4
# 2020    100         3.8  ...     2.2        0.4
#
# [11 rows x 10 columns]>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 2010 to 2020
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Total                               11 non-null     int64
#  1   Illiterate                          11 non-null     object
#  2   literate without diploma            11 non-null     object
#  3   Primary school                      11 non-null     object
#  4   Primary education                   11 non-null     object
#  5   Junior high school and equivalent   11 non-null     object
#  6   High school and equivalent          11 non-null     object
#  7   Higher education                    11 non-null     object
#  8   Master                              11 non-null     object
#  9   Doctorate                           11 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 968.0+ bytes

# %%
#sıcaklık grafiği
plt.figure(figsize=(14,7))


plt.title("Education Level")


sns.heatmap(data.corr(), annot=True, linewidths=0.5,linecolor="blue", fmt= '.1f')


plt.xlabel("Levels")
# Out:
# Text(0.5, 6.800000000000026, 'Levels')
